# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **오디오 감정 분류 모델 생성**

# %% [markdown]
# # 라이브러리 호출

# %%
# !pip install samplerate
# Out:
# Collecting samplerate
#   Downloading samplerate-0.1.0-py2.py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 8.8 MB/s
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from samplerate) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from samplerate) (1.21.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0.0->samplerate) (2.21)
# Installing collected packages: samplerate
# Successfully installed samplerate-0.1.0

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import librosa
import librosa.display
from sklearn.preprocessing import scale
import math
import soundfile
import samplerate
import pickle
import joblib
import datetime
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings("ignore")

# 모델 불러오기
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv1D, Flatten, Embedding, MaxPooling1D,Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping


# 모델 검증 및 평가
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# - 데이터 호출

# %%
data = pd.read_csv("/content/drive/MyDrive/kt/bigproject/nemotion/final_result.csv")

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ## 오디오 어그멘테이션
# 1. 오디오 노이즈 추가
# 2. 오디오 피치 조절

# %%
def noise(data, STD_N):
  """원본 데이터에 노이즈 추가"""
  xf, sr = librosa.load("/content/drive/MyDrive/kt/bigproject/nemotion/"+ data, sr = 16000)
  RMS = math.sqrt(np.mean(xf**2))
  noise = np.random.normal(0, STD_N, xf.shape[0])
  signal_noise = xf+noise
  soundfile.write('noise/n_'+data,signal_noise,16000)

# %%
def pitch(data):
  """원본 데이터에 피치 조절"""
  xx, sr = librosa.load("/content/drive/MyDrive/kt/bigproject/nemotion/"+data, sr=16000)
  out_data1 = samplerate.resample(xx, 0.8, 'sinc_best')
  out_data2 = samplerate.resample(xx, 1.3, 'sinc_best')
  soundfile.write('pitch/h_'+data,out_data1,16000)
  soundfile.write('pitch/d_'+data,out_data2,16000)

# %%
cd /content/drive/MyDrive/kt/bigproject/nemotion
# Out:
# /content/drive/MyDrive/kt/bigproject/nemotion

# %%
for i in range(len(data)):
  noise(data["audio_name"][i].strip(),0.005)

# %%
for i in range(len(data)):
  pitch(data["audio_name"][i].strip())

# %% [markdown]
# - 실행 예시

# %%
# 노이즈 조절
xf, sr = librosa.load("/content/drive/MyDrive/kt/bigproject/nemotion/"+ data["audio_name"][0], sr = 16000)
plt.plot(xf)
plt.show()
RMS = math.sqrt(np.mean(xf**2))
STD_N = 0.01
noise = np.random.normal(0, STD_N, xf.shape[0])
signal_noise = xf+noise
plt.plot(signal_noise)
plt.show

# %%
# 피치 조절
import samplerate
import IPython.display as ipd
xx, sr = librosa.load("/content/drive/MyDrive/kt/bigproject/nemotion/"+data["audio_name"][0], sr=16000)
out_data1 = samplerate.resample(xx, 0.8, 'sinc_best')
out_data2 = samplerate.resample(xx, 1.3, 'sinc_best')

print('Higher pitch:')
ipd.display(ipd.Audio(out_data1, rate=sr))
print('Lower pitch:')
ipd.display(ipd.Audio(out_data2, rate=sr))
# Out:
# Higher pitch:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Lower pitch:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 파일 저장
import soundfile
soundfile.write('noise/n_'+data["audio_name"][0],signal_noise,16000)

# %% [markdown]
# - 오디오 데이터 어그멘테이션 추가 라벨링

# %%
noise_list = os.listdir('./noise')
pitch_list = os.listdir('./pitch')

# %%
tmp = []
for i in range(len(noise_list)):
  tmp.append([noise_list[i],list(data[data["audio_name"].str.contains(noise_list[i][2:])]["emotion"])[0]])
data = data.append(pd.DataFrame(tmp, columns=['audio_name','emotion']))

# %%
tmp2 = []
for i in range(len(pitch_list)):
  tmp2.append([pitch_list[i],list(data[data["audio_name"].str.contains(pitch_list[i][2:])]["emotion"])[0]])
data = data.append(pd.DataFrame(tmp2, columns=['audio_name','emotion']))

# %%
data.reset_index(inplace=True)
del data["index"]

# %%
data.to_csv("final_result.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# ## 오디오 피쳐 추출

# %% [markdown]
# - mfcc로 데이터 특징 추출
#   - 파라미터
#     - n_mfcc : 26
#     - sr : 16000
#     - n_fft : 400
#     - hop_length = 160

# %%
x = []
for i in tqdm(range(len(data))):
  if data["audio_name"][i][0] == 'n':
    xf, sr = librosa.load("/content/drive/MyDrive/kt/bigproject/nemotion/noise/"+ data["audio_name"][i], sr = 16000)
  elif data["audio_name"][i][0] == 'd' or data["audio_name"][i][0] == 'h':
    xf, sr = librosa.load("/content/drive/MyDrive/kt/bigproject/nemotion/pitch/"+ data["audio_name"][i], sr = 16000)
  else:
    xf, sr = librosa.load("/content/drive/MyDrive/kt/bigproject/nemotion/origin/"+ data["audio_name"][i].strip(), sr = 16000)
  mfcc_1 = librosa.feature.mfcc(y=xf, sr=16000, n_mfcc=5, n_fft=400, hop_length = 160)
  # mfcc_1 = scale(mfcc_1, axis=1)
  feature = data["audio_name"][i]
  feature = np.append(feature, np.mean(mfcc_1.T, axis=0))
  x.append(feature)
# Out:
# 100%|██████████| 1180/1180 [07:28<00:00,  2.63it/s]

# %%
# librosa.display.specshow(mfcc_1)

# %% [markdown]
# - 추출한 특징 저장

# %%
today = datetime.datetime.today()
save_folder_name = str(today).split(".")[0].replace(" ", "_").replace(":", "_")[:-3]

# %%
cd /content/drive/MyDrive/kt/bigproject/nemotion
# Out:
# /content/drive/MyDrive/kt/bigproject/nemotion

# %%
with open("base_x_feature"+save_folder_name+".pickle","wb") as fw:
    pickle.dump(x, fw)

# %% [markdown]
# ## 데이터 정리

# %% [markdown]
# - mfcc로 데이터 특징 추출한 파일 호출

# %%
cd /content/drive/MyDrive/kt/bigproject/nemotion
# Out:
# /content/drive/MyDrive/kt/bigproject/nemotion

# %%
with open('base_x_feature2022-05-08_19_36.pickle', 'rb') as f:
    x = pickle.load(f)

# %%
x = pd.DataFrame(x)
x.head(2)
# Out:
#                    0         1         2          3          4           5
# 0  1651753197166.wav  -566.843  70.81106  17.963993   10.04262  -11.183487
# 1  1651754164847.wav  -599.074  47.51433  15.505734  10.031389  -16.752226

# %%
x["audio_name"]= x[0] 
x.drop(0,axis=1, inplace=True)
dff = pd.merge(x,data,on="audio_name")

# %%
x = dff.drop(["audio_name","emotion"], axis=1)
y = dff.loc[:,"emotion"]

# %%
x = x.astype('float')

# %% [markdown]
# ## 데이터 분할

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42, stratify=y_train)

# %% [markdown]
# ## 스케일링

# %%
x_train_s = x_train.copy()
x_val_s = x_val.copy()
x_test_s = x_test.copy()

# %%
scaler = MinMaxScaler()
x_train_s = scaler.fit_transform(x_train_s)
x_val_s = scaler.transform(x_val_s)
x_test_s = scaler.transform(x_test_s)

# %% [markdown]
# # 모델링

# %% [markdown]
# ## 머신러닝

# %%
val_pred_result = {}
test_pred_result = {}

# %% [markdown]
# ### 1. SVM

# %%
# train 데이터 학습하기
svm_model = SVC()
params = {'C': [1, 10],
              'gamma': [1, 0.1],
              'kernel': ['rbf']}
 
model_svm = GridSearchCV(svm_model, params, refit = True, scoring='accuracy', verbose = 3)
model_svm.fit(x_train_s, y_train)
print(model_svm.best_params_)
print(model_svm.best_score_)

print("====="*20)
print("================== val 데이터로 평가 ====================")
y_pred = model_svm.predict(x_val_s)
print(confusion_matrix(y_val, y_pred))
print(classification_report(y_val, y_pred))
val_pred_result['SVM'] = [accuracy_score(y_val, y_pred)]

print("====="*20)
print("================== test 데이터로 평가 ====================")
y_pred_test = model_svm.predict(x_test)
print(confusion_matrix(y_test, y_pred_test))
print(classification_report(y_test, y_pred_test))
test_pred_result['SVM'] = [accuracy_score(y_test, y_pred_test)]
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.430 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.364 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.430 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.450 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.411 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.371 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.377 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.377 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.377 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.377 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.404 total time=   0.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.437 total time=   0.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.464 total time=   0.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.430 total time=   0.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.490 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.417 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.351 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.377 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.417 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.384 total time=   0.0s
# {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 0.44503311258278144
# ====================================================================================================
# ================== val 데이터로 평가 ====================
# [[46 15  4]
#  [30 37  4]
#  [28 22  3]]
#               precision    recall  f1-score   support
#
#        anger       0.44      0.71      0.54        65
#    happiness       0.50      0.52      0.51        71
#          sad       0.27      0.06      0.09        53
#
#     accuracy                           0.46       189
#    macro avg       0.41      0.43      0.38       189
# weighted avg       0.42      0.46      0.41       189
#
# ====================================================================================================
# ================== test 데이터로 평가 ====================
# [[ 0 81  0]
#  [ 0 89  0]
#  [ 0 66  0]]
#               precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00        81
#    happiness       0.38      1.00      0.55        89
#          sad       0.00      0.00      0.00        66
#
#     accuracy                           0.38       236
#    macro avg       0.13      0.33      0.18       236
# weighted avg       0.14      0.38      0.21       236

# %% [markdown]
# ### 2. RandomForest

# %%
# train 데이터 학습하기
rf_model = RandomForestClassifier(random_state = 42)
params = {
    'max_depth': range(3,6),
    'n_estimators': range(50,500,50),
    'min_samples_leaf':range(8,16,4)
}
model_rf = GridSearchCV(rf_model,params, cv=3, scoring='accuracy', verbose = 3)
model_rf.fit(x_train,y_train)
print(model_rf.best_params_)
print(model_rf.best_score_)

print("====="*20)
print("================== val 데이터로 평가 ====================")
y_pred = model_rf.predict(x_val)
print(confusion_matrix(y_val, y_pred))
print(classification_report(y_val, y_pred))
val_pred_result['RandomForest'] = [accuracy_score(y_val, y_pred)]

print("====="*20)
print("================== test 데이터로 평가 ====================")
y_pred_test = model_rf.predict(x_test)
print(confusion_matrix(y_test, y_pred_test))
print(classification_report(y_test, y_pred_test))
test_pred_result['RandomForest'] = [accuracy_score(y_test, y_pred_test)]
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [CV 1/3] END max_depth=3, min_samples_leaf=8, n_estimators=50;, score=0.401 total time=   0.1s
# [CV 2/3] END max_depth=3, min_samples_leaf=8, n_estimators=50;, score=0.433 total time=   0.1s
# [CV 3/3] END max_depth=3, min_samples_leaf=8, n_estimators=50;, score=0.458 total time=   0.1s
# [CV 1/3] END max_depth=3, min_samples_leaf=8, n_estimators=100;, score=0.397 total time=   0.2s
# [CV 2/3] END max_depth=3, min_samples_leaf=8, n_estimators=100;, score=0.440 total time=   0.2s
# [CV 3/3] END max_depth=3, min_samples_leaf=8, n_estimators=100;, score=0.458 total time=   0.2s
# [CV 1/3] END max_depth=3, min_samples_leaf=8, n_estimators=150;, score=0.401 total time=   0.3s
# [CV 2/3] END max_depth=3, min_samples_leaf=8, n_estimators=150;, score=0.448 total time=   0.2s
# [CV 3/3] END max_depth=3, min_samples_leaf=8, n_estimators=150;, score=0.450 total time=   0.3s
# [CV 1/3] END max_depth=3, min_samples_leaf=8, n_estimators=200;, score=0.413 total time=   0.3s
# [CV 2/3] END max_depth=3, min_samples_leaf=8, n_estimators=200;, score=0.425 total time=   0.3s
# [CV 3/3] END max_depth=3, min_samples_leaf=8, n_estimators=200;, score=0.446 total time=   0.3s
# [CV 1/3] END max_depth=3, min_samples_leaf=8, n_estimators=250;, score=0.405 total time=   0.4s
# [CV 2/3] END max_depth=3, min_samples_leaf=8, n_estimators=250;, score=0.444 total time=   0.4s
# [CV 3/3] END max_depth=3, min_samples_leaf=8, n_estimators=250;, score=0.450 total time=   0.4s
# [CV 1/3] END max_depth=3, min_samples_leaf=8, n_estimators=300;, score=0.401 total time=   0.5s
# [CV 2/3] END max_depth=3, min_samples_leaf=8, n_estimators=300;, score=0.437 total time=   0.5s
# [CV 3/3] END max_depth=3, min_samples_leaf=8, n_estimators=300;, score=0.450 total time=   0.5s
# [CV 1/3] END max_depth=3, min_samples_leaf=8, n_estimators=350;, score=0.401 total time=   0.6s
# [CV 2/3] END max_depth=3, min_samples_leaf=8, n_estimators=350;, score=0.425 total time=   0.6s
# [CV 3/3] END max_depth=3, min_samples_leaf=8, n_estimators=350;, score=0.454 total time=   0.6s
# [CV 1/3] END max_depth=3, min_samples_leaf=8, n_estimators=400;, score=0.401 total time=   0.7s
# [CV 2/3] END max_depth=3, min_samples_leaf=8, n_estimators=400;, score=0.433 total time=   0.7s
# [CV 3/3] END max_depth=3, min_samples_leaf=8, n_estimators=400;, score=0.454 total time=   0.7s
# [CV 1/3] END max_depth=3, min_samples_leaf=8, n_estimators=450;, score=0.397 total time=   0.8s
# [CV 2/3] END max_depth=3, min_samples_leaf=8, n_estimators=450;, score=0.444 total time=   0.7s
# [CV 3/3] END max_depth=3, min_samples_leaf=8, n_estimators=450;, score=0.458 total time=   0.7s
# [CV 1/3] END max_depth=3, min_samples_leaf=12, n_estimators=50;, score=0.409 total time=   0.1s
# [CV 2/3] END max_depth=3, min_samples_leaf=12, n_estimators=50;, score=0.444 total time=   0.1s
# [CV 3/3] END max_depth=3, min_samples_leaf=12, n_estimators=50;, score=0.450 total time=   0.1s
# [CV 1/3] END max_depth=3, min_samples_leaf=12, n_estimators=100;, score=0.405 total time=   0.2s
# [CV 2/3] END max_depth=3, min_samples_leaf=12, n_estimators=100;, score=0.444 total time=   0.2s
# [CV 3/3] END max_depth=3, min_samples_leaf=12, n_estimators=100;, score=0.434 total time=   0.2s
# [CV 1/3] END max_depth=3, min_samples_leaf=12, n_estimators=150;, score=0.397 total time=   0.2s
# [CV 2/3] END max_depth=3, min_samples_leaf=12, n_estimators=150;, score=0.452 total time=   0.2s
# [CV 3/3] END max_depth=3, min_samples_leaf=12, n_estimators=150;, score=0.446 total time=   0.3s
# [CV 1/3] END max_depth=3, min_samples_leaf=12, n_estimators=200;, score=0.409 total time=   0.3s
# [CV 2/3] END max_depth=3, min_samples_leaf=12, n_estimators=200;, score=0.440 total time=   0.3s
# [CV 3/3] END max_depth=3, min_samples_leaf=12, n_estimators=200;, score=0.450 total time=   0.3s
# [CV 1/3] END max_depth=3, min_samples_leaf=12, n_estimators=250;, score=0.401 total time=   0.4s
# [CV 2/3] END max_depth=3, min_samples_leaf=12, n_estimators=250;, score=0.444 total time=   0.6s
# [CV 3/3] END max_depth=3, min_samples_leaf=12, n_estimators=250;, score=0.442 total time=   1.0s
# [CV 1/3] END max_depth=3, min_samples_leaf=12, n_estimators=300;, score=0.397 total time=   1.9s
# [CV 2/3] END max_depth=3, min_samples_leaf=12, n_estimators=300;, score=0.433 total time=   1.2s
# [CV 3/3] END max_depth=3, min_samples_leaf=12, n_estimators=300;, score=0.446 total time=   1.0s
# [CV 1/3] END max_depth=3, min_samples_leaf=12, n_estimators=350;, score=0.397 total time=   1.8s
# [CV 2/3] END max_depth=3, min_samples_leaf=12, n_estimators=350;, score=0.437 total time=   1.3s
# [CV 3/3] END max_depth=3, min_samples_leaf=12, n_estimators=350;, score=0.454 total time=   0.6s
# [CV 1/3] END max_depth=3, min_samples_leaf=12, n_estimators=400;, score=0.393 total time=   0.7s
# [CV 2/3] END max_depth=3, min_samples_leaf=12, n_estimators=400;, score=0.437 total time=   0.7s
# [CV 3/3] END max_depth=3, min_samples_leaf=12, n_estimators=400;, score=0.466 total time=   0.6s
# [CV 1/3] END max_depth=3, min_samples_leaf=12, n_estimators=450;, score=0.393 total time=   0.7s
# [CV 2/3] END max_depth=3, min_samples_leaf=12, n_estimators=450;, score=0.437 total time=   0.7s
# [CV 3/3] END max_depth=3, min_samples_leaf=12, n_estimators=450;, score=0.470 total time=   0.7s
# [CV 1/3] END max_depth=4, min_samples_leaf=8, n_estimators=50;, score=0.373 total time=   0.1s
# [CV 2/3] END max_depth=4, min_samples_leaf=8, n_estimators=50;, score=0.440 total time=   0.1s
# [CV 3/3] END max_depth=4, min_samples_leaf=8, n_estimators=50;, score=0.438 total time=   0.1s
# [CV 1/3] END max_depth=4, min_samples_leaf=8, n_estimators=100;, score=0.397 total time=   0.2s
# [CV 2/3] END max_depth=4, min_samples_leaf=8, n_estimators=100;, score=0.413 total time=   0.2s
# [CV 3/3] END max_depth=4, min_samples_leaf=8, n_estimators=100;, score=0.442 total time=   0.2s
# [CV 1/3] END max_depth=4, min_samples_leaf=8, n_estimators=150;, score=0.417 total time=   0.3s
# [CV 2/3] END max_depth=4, min_samples_leaf=8, n_estimators=150;, score=0.429 total time=   0.3s
# [CV 3/3] END max_depth=4, min_samples_leaf=8, n_estimators=150;, score=0.454 total time=   0.3s
# [CV 1/3] END max_depth=4, min_samples_leaf=8, n_estimators=200;, score=0.409 total time=   0.4s
# [CV 2/3] END max_depth=4, min_samples_leaf=8, n_estimators=200;, score=0.413 total time=   0.4s
# [CV 3/3] END max_depth=4, min_samples_leaf=8, n_estimators=200;, score=0.446 total time=   0.3s
# [CV 1/3] END max_depth=4, min_samples_leaf=8, n_estimators=250;, score=0.417 total time=   0.4s
# [CV 2/3] END max_depth=4, min_samples_leaf=8, n_estimators=250;, score=0.413 total time=   0.4s
# [CV 3/3] END max_depth=4, min_samples_leaf=8, n_estimators=250;, score=0.430 total time=   0.4s
# [CV 1/3] END max_depth=4, min_samples_leaf=8, n_estimators=300;, score=0.409 total time=   0.5s
# [CV 2/3] END max_depth=4, min_samples_leaf=8, n_estimators=300;, score=0.425 total time=   0.5s
# [CV 3/3] END max_depth=4, min_samples_leaf=8, n_estimators=300;, score=0.434 total time=   0.5s
# [CV 1/3] END max_depth=4, min_samples_leaf=8, n_estimators=350;, score=0.409 total time=   0.6s
# [CV 2/3] END max_depth=4, min_samples_leaf=8, n_estimators=350;, score=0.425 total time=   0.6s
# [CV 3/3] END max_depth=4, min_samples_leaf=8, n_estimators=350;, score=0.430 total time=   0.6s
# [CV 1/3] END max_depth=4, min_samples_leaf=8, n_estimators=400;, score=0.409 total time=   0.7s
# [CV 2/3] END max_depth=4, min_samples_leaf=8, n_estimators=400;, score=0.417 total time=   0.7s
# [CV 3/3] END max_depth=4, min_samples_leaf=8, n_estimators=400;, score=0.438 total time=   0.7s
# [CV 1/3] END max_depth=4, min_samples_leaf=8, n_estimators=450;, score=0.409 total time=   0.8s
# [CV 2/3] END max_depth=4, min_samples_leaf=8, n_estimators=450;, score=0.413 total time=   0.8s
# [CV 3/3] END max_depth=4, min_samples_leaf=8, n_estimators=450;, score=0.438 total time=   0.8s
# [CV 1/3] END max_depth=4, min_samples_leaf=12, n_estimators=50;, score=0.381 total time=   0.1s
# [CV 2/3] END max_depth=4, min_samples_leaf=12, n_estimators=50;, score=0.393 total time=   0.1s
# [CV 3/3] END max_depth=4, min_samples_leaf=12, n_estimators=50;, score=0.430 total time=   0.1s
# [CV 1/3] END max_depth=4, min_samples_leaf=12, n_estimators=100;, score=0.393 total time=   0.2s
# [CV 2/3] END max_depth=4, min_samples_leaf=12, n_estimators=100;, score=0.409 total time=   0.2s
# [CV 3/3] END max_depth=4, min_samples_leaf=12, n_estimators=100;, score=0.430 total time=   0.2s
# [CV 1/3] END max_depth=4, min_samples_leaf=12, n_estimators=150;, score=0.397 total time=   0.3s
# [CV 2/3] END max_depth=4, min_samples_leaf=12, n_estimators=150;, score=0.405 total time=   0.3s
# [CV 3/3] END max_depth=4, min_samples_leaf=12, n_estimators=150;, score=0.422 total time=   0.3s
# [CV 1/3] END max_depth=4, min_samples_leaf=12, n_estimators=200;, score=0.389 total time=   0.3s
# [CV 2/3] END max_depth=4, min_samples_leaf=12, n_estimators=200;, score=0.409 total time=   0.4s
# [CV 3/3] END max_depth=4, min_samples_leaf=12, n_estimators=200;, score=0.438 total time=   0.3s
# [CV 1/3] END max_depth=4, min_samples_leaf=12, n_estimators=250;, score=0.385 total time=   0.4s
# [CV 2/3] END max_depth=4, min_samples_leaf=12, n_estimators=250;, score=0.417 total time=   0.4s
# [CV 3/3] END max_depth=4, min_samples_leaf=12, n_estimators=250;, score=0.430 total time=   0.4s
# [CV 1/3] END max_depth=4, min_samples_leaf=12, n_estimators=300;, score=0.389 total time=   0.5s
# [CV 2/3] END max_depth=4, min_samples_leaf=12, n_estimators=300;, score=0.413 total time=   0.5s
# [CV 3/3] END max_depth=4, min_samples_leaf=12, n_estimators=300;, score=0.434 total time=   0.5s
# [CV 1/3] END max_depth=4, min_samples_leaf=12, n_estimators=350;, score=0.401 total time=   0.6s
# [CV 2/3] END max_depth=4, min_samples_leaf=12, n_estimators=350;, score=0.417 total time=   0.6s
# [CV 3/3] END max_depth=4, min_samples_leaf=12, n_estimators=350;, score=0.442 total time=   0.6s
# [CV 1/3] END max_depth=4, min_samples_leaf=12, n_estimators=400;, score=0.397 total time=   0.7s
# [CV 2/3] END max_depth=4, min_samples_leaf=12, n_estimators=400;, score=0.421 total time=   0.7s
# [CV 3/3] END max_depth=4, min_samples_leaf=12, n_estimators=400;, score=0.442 total time=   0.7s
# [CV 1/3] END max_depth=4, min_samples_leaf=12, n_estimators=450;, score=0.385 total time=   0.8s
# [CV 2/3] END max_depth=4, min_samples_leaf=12, n_estimators=450;, score=0.425 total time=   0.8s
# [CV 3/3] END max_depth=4, min_samples_leaf=12, n_estimators=450;, score=0.442 total time=   0.8s
# [CV 1/3] END max_depth=5, min_samples_leaf=8, n_estimators=50;, score=0.393 total time=   0.1s
# [CV 2/3] END max_depth=5, min_samples_leaf=8, n_estimators=50;, score=0.429 total time=   0.1s
# [CV 3/3] END max_depth=5, min_samples_leaf=8, n_estimators=50;, score=0.430 total time=   0.1s
# [CV 1/3] END max_depth=5, min_samples_leaf=8, n_estimators=100;, score=0.397 total time=   0.8s
# [CV 2/3] END max_depth=5, min_samples_leaf=8, n_estimators=100;, score=0.413 total time=   0.4s
# [CV 3/3] END max_depth=5, min_samples_leaf=8, n_estimators=100;, score=0.434 total time=   0.2s
# [CV 1/3] END max_depth=5, min_samples_leaf=8, n_estimators=150;, score=0.413 total time=   0.3s
# [CV 2/3] END max_depth=5, min_samples_leaf=8, n_estimators=150;, score=0.413 total time=   0.3s
# [CV 3/3] END max_depth=5, min_samples_leaf=8, n_estimators=150;, score=0.434 total time=   0.3s
# [CV 1/3] END max_depth=5, min_samples_leaf=8, n_estimators=200;, score=0.397 total time=   0.4s
# [CV 2/3] END max_depth=5, min_samples_leaf=8, n_estimators=200;, score=0.417 total time=   0.4s
# [CV 3/3] END max_depth=5, min_samples_leaf=8, n_estimators=200;, score=0.434 total time=   0.4s
# [CV 1/3] END max_depth=5, min_samples_leaf=8, n_estimators=250;, score=0.393 total time=   0.4s
# [CV 2/3] END max_depth=5, min_samples_leaf=8, n_estimators=250;, score=0.425 total time=   0.4s
# [CV 3/3] END max_depth=5, min_samples_leaf=8, n_estimators=250;, score=0.422 total time=   0.4s
# [CV 1/3] END max_depth=5, min_samples_leaf=8, n_estimators=300;, score=0.401 total time=   0.5s
# [CV 2/3] END max_depth=5, min_samples_leaf=8, n_estimators=300;, score=0.425 total time=   0.5s
# [CV 3/3] END max_depth=5, min_samples_leaf=8, n_estimators=300;, score=0.422 total time=   0.5s
# [CV 1/3] END max_depth=5, min_samples_leaf=8, n_estimators=350;, score=0.401 total time=   0.6s
# [CV 2/3] END max_depth=5, min_samples_leaf=8, n_estimators=350;, score=0.425 total time=   0.6s
# [CV 3/3] END max_depth=5, min_samples_leaf=8, n_estimators=350;, score=0.426 total time=   0.6s
# [CV 1/3] END max_depth=5, min_samples_leaf=8, n_estimators=400;, score=0.405 total time=   0.7s
# [CV 2/3] END max_depth=5, min_samples_leaf=8, n_estimators=400;, score=0.421 total time=   0.7s
# [CV 3/3] END max_depth=5, min_samples_leaf=8, n_estimators=400;, score=0.418 total time=   0.7s
# [CV 1/3] END max_depth=5, min_samples_leaf=8, n_estimators=450;, score=0.401 total time=   0.8s
# [CV 2/3] END max_depth=5, min_samples_leaf=8, n_estimators=450;, score=0.421 total time=   0.8s
# [CV 3/3] END max_depth=5, min_samples_leaf=8, n_estimators=450;, score=0.414 total time=   0.8s
# [CV 1/3] END max_depth=5, min_samples_leaf=12, n_estimators=50;, score=0.405 total time=   0.1s
# [CV 2/3] END max_depth=5, min_samples_leaf=12, n_estimators=50;, score=0.409 total time=   0.1s
# [CV 3/3] END max_depth=5, min_samples_leaf=12, n_estimators=50;, score=0.422 total time=   0.1s
# [CV 1/3] END max_depth=5, min_samples_leaf=12, n_estimators=100;, score=0.397 total time=   0.2s
# [CV 2/3] END max_depth=5, min_samples_leaf=12, n_estimators=100;, score=0.413 total time=   0.2s
# [CV 3/3] END max_depth=5, min_samples_leaf=12, n_estimators=100;, score=0.414 total time=   0.2s
# [CV 1/3] END max_depth=5, min_samples_leaf=12, n_estimators=150;, score=0.401 total time=   0.3s
# [CV 2/3] END max_depth=5, min_samples_leaf=12, n_estimators=150;, score=0.433 total time=   0.3s
# [CV 3/3] END max_depth=5, min_samples_leaf=12, n_estimators=150;, score=0.434 total time=   0.3s
# [CV 1/3] END max_depth=5, min_samples_leaf=12, n_estimators=200;, score=0.389 total time=   0.3s
# [CV 2/3] END max_depth=5, min_samples_leaf=12, n_estimators=200;, score=0.425 total time=   0.3s
# [CV 3/3] END max_depth=5, min_samples_leaf=12, n_estimators=200;, score=0.442 total time=   0.4s
# [CV 1/3] END max_depth=5, min_samples_leaf=12, n_estimators=250;, score=0.405 total time=   0.4s
# [CV 2/3] END max_depth=5, min_samples_leaf=12, n_estimators=250;, score=0.425 total time=   0.4s
# [CV 3/3] END max_depth=5, min_samples_leaf=12, n_estimators=250;, score=0.426 total time=   0.4s
# [CV 1/3] END max_depth=5, min_samples_leaf=12, n_estimators=300;, score=0.393 total time=   0.5s
# [CV 2/3] END max_depth=5, min_samples_leaf=12, n_estimators=300;, score=0.417 total time=   0.5s
# [CV 3/3] END max_depth=5, min_samples_leaf=12, n_estimators=300;, score=0.442 total time=   0.5s
# [CV 1/3] END max_depth=5, min_samples_leaf=12, n_estimators=350;, score=0.397 total time=   0.6s
# [CV 2/3] END max_depth=5, min_samples_leaf=12, n_estimators=350;, score=0.421 total time=   0.6s
# [CV 3/3] END max_depth=5, min_samples_leaf=12, n_estimators=350;, score=0.454 total time=   0.6s
# [CV 1/3] END max_depth=5, min_samples_leaf=12, n_estimators=400;, score=0.397 total time=   0.7s
# [CV 2/3] END max_depth=5, min_samples_leaf=12, n_estimators=400;, score=0.425 total time=   0.7s
# [CV 3/3] END max_depth=5, min_samples_leaf=12, n_estimators=400;, score=0.454 total time=   0.7s
# [CV 1/3] END max_depth=5, min_samples_leaf=12, n_estimators=450;, score=0.405 total time=   0.8s
# [CV 2/3] END max_depth=5, min_samples_leaf=12, n_estimators=450;, score=0.425 total time=   0.8s
# [CV 3/3] END max_depth=5, min_samples_leaf=12, n_estimators=450;, score=0.458 total time=   0.8s
# {'max_depth': 3, 'min_samples_leaf': 12, 'n_estimators': 50}
# 0.43445793545395134
# ====================================================================================================
# ================== val 데이터로 평가 ====================
# [[25 34  6]
#  [20 44  7]
#  [14 33  6]]
#               precision    recall  f1-score   support
#
#        anger       0.42      0.38      0.40        65
#    happiness       0.40      0.62      0.48        71
#          sad       0.32      0.11      0.17        53
#
#     accuracy                           0.40       189
#    macro avg       0.38      0.37      0.35       189
# weighted avg       0.38      0.40      0.37       189
#
# ====================================================================================================
# ================== test 데이터로 평가 ====================
# [[22 52  7]
#  [23 56 10]
#  [10 40 16]]
#               precision    recall  f1-score   support
#
#        anger       0.40      0.27      0.32        81
#    happiness       0.38      0.63      0.47        89
#          sad       0.48      0.24      0.32        66
#
#     accuracy                           0.40       236
#    macro avg       0.42      0.38      0.37       236
# weighted avg       0.42      0.40      0.38       236

# %% [markdown]
# ### 3. XGBoost

# %%
xgb_model = XGBClassifier(random_state = 42)

params = {
    'max_depth': range(3,9),
    'n_estimators': range(50,500,50),
    'learning_rate': [0.1,0.5]
}

model_xgb = GridSearchCV(xgb_model,params, cv=3, scoring='accuracy', verbose=3)
model_xgb.fit(x_train.values,y_train)
print(model_xgb.best_params_)
print(model_xgb.best_score_)

print("====="*20)
print("================== val 데이터로 평가 ====================")
y_pred = model_xgb.predict(x_val.values)
print(confusion_matrix(y_val, y_pred))
print(classification_report(y_val, y_pred))
val_pred_result['XGB'] = [accuracy_score(y_val, y_pred)]

print("====="*20)
print("================== test 데이터로 평가 ====================")
y_pred_test = model_xgb.predict(x_test.values)
print(confusion_matrix(y_test, y_pred_test))
print(classification_report(y_test, y_pred_test))
test_pred_result['XGB'] = [accuracy_score(y_test, y_pred_test)]
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.425 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.385 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.414 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.425 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.405 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.378 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=150;, score=0.421 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=150;, score=0.413 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=150;, score=0.406 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.409 total time=   0.2s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.413 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.398 total time=   0.2s
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=250;, score=0.405 total time=   0.2s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=250;, score=0.405 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=250;, score=0.394 total time=   0.2s
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=300;, score=0.421 total time=   0.3s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=300;, score=0.401 total time=   0.3s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=300;, score=0.406 total time=   0.3s
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=350;, score=0.413 total time=   0.3s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=350;, score=0.393 total time=   0.3s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=350;, score=0.402 total time=   0.3s
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.417 total time=   0.4s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.401 total time=   0.4s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.402 total time=   0.4s
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=450;, score=0.429 total time=   0.4s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=450;, score=0.417 total time=   0.4s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=450;, score=0.430 total time=   0.4s
# [CV 1/3] END learning_rate=0.1, max_depth=4, n_estimators=50;, score=0.429 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=4, n_estimators=50;, score=0.405 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=4, n_estimators=50;, score=0.398 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=4, n_estimators=100;, score=0.421 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=4, n_estimators=100;, score=0.417 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=4, n_estimators=100;, score=0.375 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=4, n_estimators=150;, score=0.437 total time=   0.2s
# [CV 2/3] END learning_rate=0.1, max_depth=4, n_estimators=150;, score=0.429 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, max_depth=4, n_estimators=150;, score=0.386 total time=   0.2s
# [CV 1/3] END learning_rate=0.1, max_depth=4, n_estimators=200;, score=0.433 total time=   0.2s
# [CV 2/3] END learning_rate=0.1, max_depth=4, n_estimators=200;, score=0.425 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, max_depth=4, n_estimators=200;, score=0.394 total time=   0.2s
# [CV 1/3] END learning_rate=0.1, max_depth=4, n_estimators=250;, score=0.421 total time=   0.3s
# [CV 2/3] END learning_rate=0.1, max_depth=4, n_estimators=250;, score=0.437 total time=   0.3s
# [CV 3/3] END learning_rate=0.1, max_depth=4, n_estimators=250;, score=0.390 total time=   0.3s
# [CV 1/3] END learning_rate=0.1, max_depth=4, n_estimators=300;, score=0.433 total time=   0.4s
# [CV 2/3] END learning_rate=0.1, max_depth=4, n_estimators=300;, score=0.429 total time=   0.4s
# [CV 3/3] END learning_rate=0.1, max_depth=4, n_estimators=300;, score=0.402 total time=   0.4s
# [CV 1/3] END learning_rate=0.1, max_depth=4, n_estimators=350;, score=0.444 total time=   0.4s
# [CV 2/3] END learning_rate=0.1, max_depth=4, n_estimators=350;, score=0.440 total time=   0.4s
# [CV 3/3] END learning_rate=0.1, max_depth=4, n_estimators=350;, score=0.406 total time=   0.4s
# [CV 1/3] END learning_rate=0.1, max_depth=4, n_estimators=400;, score=0.452 total time=   0.5s
# [CV 2/3] END learning_rate=0.1, max_depth=4, n_estimators=400;, score=0.433 total time=   0.5s
# [CV 3/3] END learning_rate=0.1, max_depth=4, n_estimators=400;, score=0.406 total time=   0.5s
# [CV 1/3] END learning_rate=0.1, max_depth=4, n_estimators=450;, score=0.464 total time=   0.5s
# [CV 2/3] END learning_rate=0.1, max_depth=4, n_estimators=450;, score=0.440 total time=   0.5s
# [CV 3/3] END learning_rate=0.1, max_depth=4, n_estimators=450;, score=0.410 total time=   0.5s
# [CV 1/3] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.440 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.401 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.378 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.417 total time=   0.2s
# [CV 2/3] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.409 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.418 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=5, n_estimators=150;, score=0.421 total time=   0.2s
# [CV 2/3] END learning_rate=0.1, max_depth=5, n_estimators=150;, score=0.409 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, max_depth=5, n_estimators=150;, score=0.422 total time=   0.2s
# [CV 1/3] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.433 total time=   0.3s
# [CV 2/3] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.417 total time=   0.3s
# [CV 3/3] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.426 total time=   0.3s
# [CV 1/3] END learning_rate=0.1, max_depth=5, n_estimators=250;, score=0.437 total time=   0.4s
# [CV 2/3] END learning_rate=0.1, max_depth=5, n_estimators=250;, score=0.417 total time=   0.4s
# [CV 3/3] END learning_rate=0.1, max_depth=5, n_estimators=250;, score=0.422 total time=   0.4s
# [CV 1/3] END learning_rate=0.1, max_depth=5, n_estimators=300;, score=0.440 total time=   0.4s
# [CV 2/3] END learning_rate=0.1, max_depth=5, n_estimators=300;, score=0.425 total time=   0.4s
# [CV 3/3] END learning_rate=0.1, max_depth=5, n_estimators=300;, score=0.418 total time=   0.5s
# [CV 1/3] END learning_rate=0.1, max_depth=5, n_estimators=350;, score=0.425 total time=   1.0s
# [CV 2/3] END learning_rate=0.1, max_depth=5, n_estimators=350;, score=0.413 total time=   0.5s
# [CV 3/3] END learning_rate=0.1, max_depth=5, n_estimators=350;, score=0.426 total time=   0.5s
# [CV 1/3] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.429 total time=   0.6s
# [CV 2/3] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.417 total time=   0.6s
# [CV 3/3] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.418 total time=   0.6s
# [CV 1/3] END learning_rate=0.1, max_depth=5, n_estimators=450;, score=0.433 total time=   0.6s
# [CV 2/3] END learning_rate=0.1, max_depth=5, n_estimators=450;, score=0.421 total time=   0.7s
# [CV 3/3] END learning_rate=0.1, max_depth=5, n_estimators=450;, score=0.410 total time=   0.6s
# [CV 1/3] END learning_rate=0.1, max_depth=6, n_estimators=50;, score=0.425 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=6, n_estimators=50;, score=0.393 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=6, n_estimators=50;, score=0.351 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=6, n_estimators=100;, score=0.421 total time=   0.2s
# [CV 2/3] END learning_rate=0.1, max_depth=6, n_estimators=100;, score=0.409 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, max_depth=6, n_estimators=100;, score=0.386 total time=   0.2s
# [CV 1/3] END learning_rate=0.1, max_depth=6, n_estimators=150;, score=0.425 total time=   0.3s
# [CV 2/3] END learning_rate=0.1, max_depth=6, n_estimators=150;, score=0.421 total time=   0.3s
# [CV 3/3] END learning_rate=0.1, max_depth=6, n_estimators=150;, score=0.394 total time=   0.3s
# [CV 1/3] END learning_rate=0.1, max_depth=6, n_estimators=200;, score=0.421 total time=   0.4s
# [CV 2/3] END learning_rate=0.1, max_depth=6, n_estimators=200;, score=0.409 total time=   0.4s
# [CV 3/3] END learning_rate=0.1, max_depth=6, n_estimators=200;, score=0.414 total time=   0.4s
# [CV 1/3] END learning_rate=0.1, max_depth=6, n_estimators=250;, score=0.437 total time=   0.4s
# [CV 2/3] END learning_rate=0.1, max_depth=6, n_estimators=250;, score=0.405 total time=   0.4s
# [CV 3/3] END learning_rate=0.1, max_depth=6, n_estimators=250;, score=0.418 total time=   0.4s
# [CV 1/3] END learning_rate=0.1, max_depth=6, n_estimators=300;, score=0.437 total time=   0.5s
# [CV 2/3] END learning_rate=0.1, max_depth=6, n_estimators=300;, score=0.409 total time=   0.5s
# [CV 3/3] END learning_rate=0.1, max_depth=6, n_estimators=300;, score=0.430 total time=   0.5s
# [CV 1/3] END learning_rate=0.1, max_depth=6, n_estimators=350;, score=0.456 total time=   0.7s
# [CV 2/3] END learning_rate=0.1, max_depth=6, n_estimators=350;, score=0.413 total time=   0.6s
# [CV 3/3] END learning_rate=0.1, max_depth=6, n_estimators=350;, score=0.422 total time=   0.6s
# [CV 1/3] END learning_rate=0.1, max_depth=6, n_estimators=400;, score=0.452 total time=   0.7s
# [CV 2/3] END learning_rate=0.1, max_depth=6, n_estimators=400;, score=0.409 total time=   0.7s
# [CV 3/3] END learning_rate=0.1, max_depth=6, n_estimators=400;, score=0.418 total time=   0.7s
# [CV 1/3] END learning_rate=0.1, max_depth=6, n_estimators=450;, score=0.444 total time=   0.8s
# [CV 2/3] END learning_rate=0.1, max_depth=6, n_estimators=450;, score=0.409 total time=   1.4s
# [CV 3/3] END learning_rate=0.1, max_depth=6, n_estimators=450;, score=0.414 total time=   2.0s
# [CV 1/3] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.460 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.409 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.386 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.421 total time=   0.2s
# [CV 2/3] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.405 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.378 total time=   0.2s
# [CV 1/3] END learning_rate=0.1, max_depth=7, n_estimators=150;, score=0.433 total time=   0.3s
# [CV 2/3] END learning_rate=0.1, max_depth=7, n_estimators=150;, score=0.405 total time=   0.3s
# [CV 3/3] END learning_rate=0.1, max_depth=7, n_estimators=150;, score=0.402 total time=   0.3s
# [CV 1/3] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.452 total time=   0.4s
# [CV 2/3] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.405 total time=   0.4s
# [CV 3/3] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.422 total time=   0.4s
# [CV 1/3] END learning_rate=0.1, max_depth=7, n_estimators=250;, score=0.448 total time=   0.5s
# [CV 2/3] END learning_rate=0.1, max_depth=7, n_estimators=250;, score=0.409 total time=   0.5s
# [CV 3/3] END learning_rate=0.1, max_depth=7, n_estimators=250;, score=0.426 total time=   0.5s
# [CV 1/3] END learning_rate=0.1, max_depth=7, n_estimators=300;, score=0.444 total time=   0.6s
# [CV 2/3] END learning_rate=0.1, max_depth=7, n_estimators=300;, score=0.405 total time=   0.6s
# [CV 3/3] END learning_rate=0.1, max_depth=7, n_estimators=300;, score=0.422 total time=   0.6s
# [CV 1/3] END learning_rate=0.1, max_depth=7, n_estimators=350;, score=0.444 total time=   0.7s
# [CV 2/3] END learning_rate=0.1, max_depth=7, n_estimators=350;, score=0.413 total time=   0.7s
# [CV 3/3] END learning_rate=0.1, max_depth=7, n_estimators=350;, score=0.418 total time=   0.7s
# [CV 1/3] END learning_rate=0.1, max_depth=7, n_estimators=400;, score=0.440 total time=   0.8s
# [CV 2/3] END learning_rate=0.1, max_depth=7, n_estimators=400;, score=0.421 total time=   0.8s
# [CV 3/3] END learning_rate=0.1, max_depth=7, n_estimators=400;, score=0.426 total time=   0.8s
# [CV 1/3] END learning_rate=0.1, max_depth=7, n_estimators=450;, score=0.440 total time=   0.8s
# [CV 2/3] END learning_rate=0.1, max_depth=7, n_estimators=450;, score=0.417 total time=   0.8s
# [CV 3/3] END learning_rate=0.1, max_depth=7, n_estimators=450;, score=0.422 total time=   0.8s
# [CV 1/3] END learning_rate=0.1, max_depth=8, n_estimators=50;, score=0.417 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=8, n_estimators=50;, score=0.397 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, max_depth=8, n_estimators=50;, score=0.363 total time=   0.2s
# [CV 1/3] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=0.440 total time=   0.5s
# [CV 2/3] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=0.421 total time=   0.6s
# [CV 3/3] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=0.375 total time=   0.6s
# [CV 1/3] END learning_rate=0.1, max_depth=8, n_estimators=150;, score=0.448 total time=   0.4s
# [CV 2/3] END learning_rate=0.1, max_depth=8, n_estimators=150;, score=0.429 total time=   0.4s
# [CV 3/3] END learning_rate=0.1, max_depth=8, n_estimators=150;, score=0.394 total time=   0.3s
# [CV 1/3] END learning_rate=0.1, max_depth=8, n_estimators=200;, score=0.448 total time=   0.4s
# [CV 2/3] END learning_rate=0.1, max_depth=8, n_estimators=200;, score=0.433 total time=   0.5s
# [CV 3/3] END learning_rate=0.1, max_depth=8, n_estimators=200;, score=0.398 total time=   0.4s
# [CV 1/3] END learning_rate=0.1, max_depth=8, n_estimators=250;, score=0.444 total time=   0.5s
# [CV 2/3] END learning_rate=0.1, max_depth=8, n_estimators=250;, score=0.444 total time=   0.6s
# [CV 3/3] END learning_rate=0.1, max_depth=8, n_estimators=250;, score=0.406 total time=   0.5s
# [CV 1/3] END learning_rate=0.1, max_depth=8, n_estimators=300;, score=0.448 total time=   0.7s
# [CV 2/3] END learning_rate=0.1, max_depth=8, n_estimators=300;, score=0.444 total time=   0.6s
# [CV 3/3] END learning_rate=0.1, max_depth=8, n_estimators=300;, score=0.410 total time=   0.6s
# [CV 1/3] END learning_rate=0.1, max_depth=8, n_estimators=350;, score=0.456 total time=   0.7s
# [CV 2/3] END learning_rate=0.1, max_depth=8, n_estimators=350;, score=0.433 total time=   0.7s
# [CV 3/3] END learning_rate=0.1, max_depth=8, n_estimators=350;, score=0.406 total time=   0.7s
# [CV 1/3] END learning_rate=0.1, max_depth=8, n_estimators=400;, score=0.456 total time=   0.8s
# [CV 2/3] END learning_rate=0.1, max_depth=8, n_estimators=400;, score=0.433 total time=   0.8s
# [CV 3/3] END learning_rate=0.1, max_depth=8, n_estimators=400;, score=0.414 total time=   0.8s
# [CV 1/3] END learning_rate=0.1, max_depth=8, n_estimators=450;, score=0.460 total time=   0.9s
# [CV 2/3] END learning_rate=0.1, max_depth=8, n_estimators=450;, score=0.433 total time=   0.9s
# [CV 3/3] END learning_rate=0.1, max_depth=8, n_estimators=450;, score=0.418 total time=   0.9s
# [CV 1/3] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.444 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.393 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.410 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=3, n_estimators=100;, score=0.417 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=3, n_estimators=100;, score=0.413 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=3, n_estimators=100;, score=0.422 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=3, n_estimators=150;, score=0.413 total time=   0.2s
# [CV 2/3] END learning_rate=0.5, max_depth=3, n_estimators=150;, score=0.397 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=3, n_estimators=150;, score=0.430 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=3, n_estimators=200;, score=0.440 total time=   0.2s
# [CV 2/3] END learning_rate=0.5, max_depth=3, n_estimators=200;, score=0.417 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=3, n_estimators=200;, score=0.426 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=3, n_estimators=250;, score=0.444 total time=   0.3s
# [CV 2/3] END learning_rate=0.5, max_depth=3, n_estimators=250;, score=0.425 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=3, n_estimators=250;, score=0.410 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=3, n_estimators=300;, score=0.417 total time=   0.3s
# [CV 2/3] END learning_rate=0.5, max_depth=3, n_estimators=300;, score=0.401 total time=   0.3s
# [CV 3/3] END learning_rate=0.5, max_depth=3, n_estimators=300;, score=0.398 total time=   0.3s
# [CV 1/3] END learning_rate=0.5, max_depth=3, n_estimators=350;, score=0.421 total time=   0.3s
# [CV 2/3] END learning_rate=0.5, max_depth=3, n_estimators=350;, score=0.417 total time=   0.3s
# [CV 3/3] END learning_rate=0.5, max_depth=3, n_estimators=350;, score=0.406 total time=   0.3s
# [CV 1/3] END learning_rate=0.5, max_depth=3, n_estimators=400;, score=0.417 total time=   0.4s
# [CV 2/3] END learning_rate=0.5, max_depth=3, n_estimators=400;, score=0.425 total time=   0.4s
# [CV 3/3] END learning_rate=0.5, max_depth=3, n_estimators=400;, score=0.406 total time=   0.4s
# [CV 1/3] END learning_rate=0.5, max_depth=3, n_estimators=450;, score=0.417 total time=   0.4s
# [CV 2/3] END learning_rate=0.5, max_depth=3, n_estimators=450;, score=0.444 total time=   0.4s
# [CV 3/3] END learning_rate=0.5, max_depth=3, n_estimators=450;, score=0.406 total time=   0.4s
# [CV 1/3] END learning_rate=0.5, max_depth=4, n_estimators=50;, score=0.413 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=4, n_estimators=50;, score=0.452 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=4, n_estimators=50;, score=0.402 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=4, n_estimators=100;, score=0.433 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=4, n_estimators=100;, score=0.433 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=4, n_estimators=100;, score=0.390 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=4, n_estimators=150;, score=0.425 total time=   0.2s
# [CV 2/3] END learning_rate=0.5, max_depth=4, n_estimators=150;, score=0.425 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=4, n_estimators=150;, score=0.394 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=4, n_estimators=200;, score=0.429 total time=   0.2s
# [CV 2/3] END learning_rate=0.5, max_depth=4, n_estimators=200;, score=0.417 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=4, n_estimators=200;, score=0.390 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=4, n_estimators=250;, score=0.429 total time=   0.3s
# [CV 2/3] END learning_rate=0.5, max_depth=4, n_estimators=250;, score=0.421 total time=   0.3s
# [CV 3/3] END learning_rate=0.5, max_depth=4, n_estimators=250;, score=0.386 total time=   0.3s
# [CV 1/3] END learning_rate=0.5, max_depth=4, n_estimators=300;, score=0.437 total time=   0.3s
# [CV 2/3] END learning_rate=0.5, max_depth=4, n_estimators=300;, score=0.429 total time=   0.3s
# [CV 3/3] END learning_rate=0.5, max_depth=4, n_estimators=300;, score=0.382 total time=   0.3s
# [CV 1/3] END learning_rate=0.5, max_depth=4, n_estimators=350;, score=0.425 total time=   0.4s
# [CV 2/3] END learning_rate=0.5, max_depth=4, n_estimators=350;, score=0.425 total time=   0.4s
# [CV 3/3] END learning_rate=0.5, max_depth=4, n_estimators=350;, score=0.390 total time=   0.4s
# [CV 1/3] END learning_rate=0.5, max_depth=4, n_estimators=400;, score=0.425 total time=   0.4s
# [CV 2/3] END learning_rate=0.5, max_depth=4, n_estimators=400;, score=0.425 total time=   0.5s
# [CV 3/3] END learning_rate=0.5, max_depth=4, n_estimators=400;, score=0.382 total time=   0.4s
# [CV 1/3] END learning_rate=0.5, max_depth=4, n_estimators=450;, score=0.429 total time=   0.5s
# [CV 2/3] END learning_rate=0.5, max_depth=4, n_estimators=450;, score=0.417 total time=   0.5s
# [CV 3/3] END learning_rate=0.5, max_depth=4, n_estimators=450;, score=0.386 total time=   0.5s
# [CV 1/3] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.440 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.417 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.414 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=0.421 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=0.429 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=0.426 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=5, n_estimators=150;, score=0.421 total time=   0.6s
# [CV 2/3] END learning_rate=0.5, max_depth=5, n_estimators=150;, score=0.440 total time=   0.7s
# [CV 3/3] END learning_rate=0.5, max_depth=5, n_estimators=150;, score=0.422 total time=   0.5s
# [CV 1/3] END learning_rate=0.5, max_depth=5, n_estimators=200;, score=0.409 total time=   0.7s
# [CV 2/3] END learning_rate=0.5, max_depth=5, n_estimators=200;, score=0.440 total time=   0.6s
# [CV 3/3] END learning_rate=0.5, max_depth=5, n_estimators=200;, score=0.414 total time=   0.6s
# [CV 1/3] END learning_rate=0.5, max_depth=5, n_estimators=250;, score=0.421 total time=   0.6s
# [CV 2/3] END learning_rate=0.5, max_depth=5, n_estimators=250;, score=0.421 total time=   0.7s
# [CV 3/3] END learning_rate=0.5, max_depth=5, n_estimators=250;, score=0.414 total time=   0.7s
# [CV 1/3] END learning_rate=0.5, max_depth=5, n_estimators=300;, score=0.425 total time=   0.8s
# [CV 2/3] END learning_rate=0.5, max_depth=5, n_estimators=300;, score=0.417 total time=   0.6s
# [CV 3/3] END learning_rate=0.5, max_depth=5, n_estimators=300;, score=0.418 total time=   0.7s
# [CV 1/3] END learning_rate=0.5, max_depth=5, n_estimators=350;, score=0.425 total time=   0.7s
# [CV 2/3] END learning_rate=0.5, max_depth=5, n_estimators=350;, score=0.417 total time=   0.7s
# [CV 3/3] END learning_rate=0.5, max_depth=5, n_estimators=350;, score=0.418 total time=   0.8s
# [CV 1/3] END learning_rate=0.5, max_depth=5, n_estimators=400;, score=0.425 total time=   0.8s
# [CV 2/3] END learning_rate=0.5, max_depth=5, n_estimators=400;, score=0.421 total time=   0.7s
# [CV 3/3] END learning_rate=0.5, max_depth=5, n_estimators=400;, score=0.414 total time=   1.3s
# [CV 1/3] END learning_rate=0.5, max_depth=5, n_estimators=450;, score=0.429 total time=   0.6s
# [CV 2/3] END learning_rate=0.5, max_depth=5, n_estimators=450;, score=0.417 total time=   1.2s
# [CV 3/3] END learning_rate=0.5, max_depth=5, n_estimators=450;, score=0.414 total time=   0.5s
# [CV 1/3] END learning_rate=0.5, max_depth=6, n_estimators=50;, score=0.452 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=6, n_estimators=50;, score=0.413 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=6, n_estimators=50;, score=0.414 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=6, n_estimators=100;, score=0.433 total time=   0.2s
# [CV 2/3] END learning_rate=0.5, max_depth=6, n_estimators=100;, score=0.417 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=6, n_estimators=100;, score=0.418 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=6, n_estimators=150;, score=0.433 total time=   0.2s
# [CV 2/3] END learning_rate=0.5, max_depth=6, n_estimators=150;, score=0.401 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=6, n_estimators=150;, score=0.418 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=6, n_estimators=200;, score=0.433 total time=   0.3s
# [CV 2/3] END learning_rate=0.5, max_depth=6, n_estimators=200;, score=0.409 total time=   0.3s
# [CV 3/3] END learning_rate=0.5, max_depth=6, n_estimators=200;, score=0.414 total time=   0.3s
# [CV 1/3] END learning_rate=0.5, max_depth=6, n_estimators=250;, score=0.425 total time=   0.4s
# [CV 2/3] END learning_rate=0.5, max_depth=6, n_estimators=250;, score=0.417 total time=   0.4s
# [CV 3/3] END learning_rate=0.5, max_depth=6, n_estimators=250;, score=0.414 total time=   0.4s
# [CV 1/3] END learning_rate=0.5, max_depth=6, n_estimators=300;, score=0.437 total time=   0.4s
# [CV 2/3] END learning_rate=0.5, max_depth=6, n_estimators=300;, score=0.413 total time=   0.4s
# [CV 3/3] END learning_rate=0.5, max_depth=6, n_estimators=300;, score=0.406 total time=   0.4s
# [CV 1/3] END learning_rate=0.5, max_depth=6, n_estimators=350;, score=0.437 total time=   0.4s
# [CV 2/3] END learning_rate=0.5, max_depth=6, n_estimators=350;, score=0.413 total time=   0.4s
# [CV 3/3] END learning_rate=0.5, max_depth=6, n_estimators=350;, score=0.418 total time=   0.4s
# [CV 1/3] END learning_rate=0.5, max_depth=6, n_estimators=400;, score=0.437 total time=   0.5s
# [CV 2/3] END learning_rate=0.5, max_depth=6, n_estimators=400;, score=0.417 total time=   0.5s
# [CV 3/3] END learning_rate=0.5, max_depth=6, n_estimators=400;, score=0.418 total time=   0.5s
# [CV 1/3] END learning_rate=0.5, max_depth=6, n_estimators=450;, score=0.437 total time=   0.5s
# [CV 2/3] END learning_rate=0.5, max_depth=6, n_estimators=450;, score=0.417 total time=   0.5s
# [CV 3/3] END learning_rate=0.5, max_depth=6, n_estimators=450;, score=0.422 total time=   0.5s
# [CV 1/3] END learning_rate=0.5, max_depth=7, n_estimators=50;, score=0.421 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=7, n_estimators=50;, score=0.433 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=7, n_estimators=50;, score=0.394 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=7, n_estimators=100;, score=0.429 total time=   0.2s
# [CV 2/3] END learning_rate=0.5, max_depth=7, n_estimators=100;, score=0.433 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=7, n_estimators=100;, score=0.394 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=7, n_estimators=150;, score=0.433 total time=   0.3s
# [CV 2/3] END learning_rate=0.5, max_depth=7, n_estimators=150;, score=0.429 total time=   0.3s
# [CV 3/3] END learning_rate=0.5, max_depth=7, n_estimators=150;, score=0.398 total time=   0.3s
# [CV 1/3] END learning_rate=0.5, max_depth=7, n_estimators=200;, score=0.433 total time=   0.3s
# [CV 2/3] END learning_rate=0.5, max_depth=7, n_estimators=200;, score=0.425 total time=   0.3s
# [CV 3/3] END learning_rate=0.5, max_depth=7, n_estimators=200;, score=0.402 total time=   0.3s
# [CV 1/3] END learning_rate=0.5, max_depth=7, n_estimators=250;, score=0.437 total time=   0.4s
# [CV 2/3] END learning_rate=0.5, max_depth=7, n_estimators=250;, score=0.433 total time=   0.4s
# [CV 3/3] END learning_rate=0.5, max_depth=7, n_estimators=250;, score=0.398 total time=   0.4s
# [CV 1/3] END learning_rate=0.5, max_depth=7, n_estimators=300;, score=0.437 total time=   0.4s
# [CV 2/3] END learning_rate=0.5, max_depth=7, n_estimators=300;, score=0.429 total time=   0.4s
# [CV 3/3] END learning_rate=0.5, max_depth=7, n_estimators=300;, score=0.394 total time=   0.5s
# [CV 1/3] END learning_rate=0.5, max_depth=7, n_estimators=350;, score=0.437 total time=   0.5s
# [CV 2/3] END learning_rate=0.5, max_depth=7, n_estimators=350;, score=0.429 total time=   0.4s
# [CV 3/3] END learning_rate=0.5, max_depth=7, n_estimators=350;, score=0.398 total time=   0.5s
# [CV 1/3] END learning_rate=0.5, max_depth=7, n_estimators=400;, score=0.429 total time=   0.5s
# [CV 2/3] END learning_rate=0.5, max_depth=7, n_estimators=400;, score=0.429 total time=   0.5s
# [CV 3/3] END learning_rate=0.5, max_depth=7, n_estimators=400;, score=0.406 total time=   0.5s
# [CV 1/3] END learning_rate=0.5, max_depth=7, n_estimators=450;, score=0.429 total time=   0.5s
# [CV 2/3] END learning_rate=0.5, max_depth=7, n_estimators=450;, score=0.429 total time=   0.5s
# [CV 3/3] END learning_rate=0.5, max_depth=7, n_estimators=450;, score=0.402 total time=   0.5s
# [CV 1/3] END learning_rate=0.5, max_depth=8, n_estimators=50;, score=0.425 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=8, n_estimators=50;, score=0.421 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=8, n_estimators=50;, score=0.418 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=8, n_estimators=100;, score=0.440 total time=   0.2s
# [CV 2/3] END learning_rate=0.5, max_depth=8, n_estimators=100;, score=0.417 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=8, n_estimators=100;, score=0.414 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=8, n_estimators=150;, score=0.433 total time=   0.3s
# [CV 2/3] END learning_rate=0.5, max_depth=8, n_estimators=150;, score=0.413 total time=   0.3s
# [CV 3/3] END learning_rate=0.5, max_depth=8, n_estimators=150;, score=0.418 total time=   0.3s
# [CV 1/3] END learning_rate=0.5, max_depth=8, n_estimators=200;, score=0.444 total time=   0.3s
# [CV 2/3] END learning_rate=0.5, max_depth=8, n_estimators=200;, score=0.413 total time=   0.3s
# [CV 3/3] END learning_rate=0.5, max_depth=8, n_estimators=200;, score=0.422 total time=   0.3s
# [CV 1/3] END learning_rate=0.5, max_depth=8, n_estimators=250;, score=0.437 total time=   0.4s
# [CV 2/3] END learning_rate=0.5, max_depth=8, n_estimators=250;, score=0.413 total time=   0.4s
# [CV 3/3] END learning_rate=0.5, max_depth=8, n_estimators=250;, score=0.422 total time=   0.4s
# [CV 1/3] END learning_rate=0.5, max_depth=8, n_estimators=300;, score=0.440 total time=   0.4s
# [CV 2/3] END learning_rate=0.5, max_depth=8, n_estimators=300;, score=0.417 total time=   0.4s
# [CV 3/3] END learning_rate=0.5, max_depth=8, n_estimators=300;, score=0.418 total time=   0.4s
# [CV 1/3] END learning_rate=0.5, max_depth=8, n_estimators=350;, score=0.429 total time=   0.5s
# [CV 2/3] END learning_rate=0.5, max_depth=8, n_estimators=350;, score=0.413 total time=   0.4s
# [CV 3/3] END learning_rate=0.5, max_depth=8, n_estimators=350;, score=0.422 total time=   0.5s
# [CV 1/3] END learning_rate=0.5, max_depth=8, n_estimators=400;, score=0.421 total time=   0.5s
# [CV 2/3] END learning_rate=0.5, max_depth=8, n_estimators=400;, score=0.417 total time=   0.5s
# [CV 3/3] END learning_rate=0.5, max_depth=8, n_estimators=400;, score=0.418 total time=   0.5s
# [CV 1/3] END learning_rate=0.5, max_depth=8, n_estimators=450;, score=0.425 total time=   0.5s
# [CV 2/3] END learning_rate=0.5, max_depth=8, n_estimators=450;, score=0.425 total time=   0.5s
# [CV 3/3] END learning_rate=0.5, max_depth=8, n_estimators=450;, score=0.422 total time=   0.5s
# {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 450}
# 0.4383734901663188
# ====================================================================================================
# ================== val 데이터로 평가 ====================
# [[29 18 18]
#  [18 39 14]
#  [17 19 17]]
#               precision    recall  f1-score   support
#
#        anger       0.45      0.45      0.45        65
#    happiness       0.51      0.55      0.53        71
#          sad       0.35      0.32      0.33        53
#
#     accuracy                           0.45       189
#    macro avg       0.44      0.44      0.44       189
# weighted avg       0.45      0.45      0.45       189
#
# ====================================================================================================
# ================== test 데이터로 평가 ====================
# [[30 36 15]
#  [30 37 22]
#  [15 26 25]]
#               precision    recall  f1-score   support
#
#        anger       0.40      0.37      0.38        81
#    happiness       0.37      0.42      0.39        89
#          sad       0.40      0.38      0.39        66
#
#     accuracy                           0.39       236
#    macro avg       0.39      0.39      0.39       236
# weighted avg       0.39      0.39      0.39       236

# %% [markdown]
# ### 4. LightGBM

# %%
lgbm_model = LGBMClassifier(random_state = 42)

params = {
    'max_depth': range(3,9),
    'n_estimators': range(30,200,50),
    'learning_rate': [0.1,0.5]
}

model_lgbm = GridSearchCV(lgbm_model,params, cv=3, scoring='accuracy', verbose=3)
model_lgbm.fit(x_train.values,y_train)
print(model_lgbm.best_params_)
print(model_lgbm.best_score_)

print("====="*20)
print("================== val 데이터로 평가 ====================")
y_pred = model_lgbm.predict(x_val)
print(confusion_matrix(y_val, y_pred))
print(classification_report(y_val, y_pred))
val_pred_result['LGBM'] = [accuracy_score(y_val, y_pred)]

print("====="*20)
print("================== test 데이터로 평가 ====================")
y_pred_test = model_lgbm.predict(x_test.values)
print(confusion_matrix(y_test, y_pred_test))
print(classification_report(y_test, y_pred_test))
test_pred_result['LGBM'] = [accuracy_score(y_test, y_pred_test)]
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=30;, score=0.381 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=30;, score=0.381 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=30;, score=0.402 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=80;, score=0.385 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=80;, score=0.413 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=80;, score=0.394 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=130;, score=0.397 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=130;, score=0.417 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=130;, score=0.418 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=180;, score=0.397 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=180;, score=0.417 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=180;, score=0.418 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=4, n_estimators=30;, score=0.417 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, max_depth=4, n_estimators=30;, score=0.409 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, max_depth=4, n_estimators=30;, score=0.394 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, max_depth=4, n_estimators=80;, score=0.401 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=4, n_estimators=80;, score=0.421 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=4, n_estimators=80;, score=0.402 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=4, n_estimators=130;, score=0.401 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=4, n_estimators=130;, score=0.440 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=4, n_estimators=130;, score=0.398 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=4, n_estimators=180;, score=0.405 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=4, n_estimators=180;, score=0.460 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=4, n_estimators=180;, score=0.402 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=5, n_estimators=30;, score=0.405 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, max_depth=5, n_estimators=30;, score=0.405 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, max_depth=5, n_estimators=30;, score=0.398 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, max_depth=5, n_estimators=80;, score=0.421 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=5, n_estimators=80;, score=0.405 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=5, n_estimators=80;, score=0.394 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=5, n_estimators=130;, score=0.425 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=5, n_estimators=130;, score=0.409 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=5, n_estimators=130;, score=0.406 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=5, n_estimators=180;, score=0.437 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=5, n_estimators=180;, score=0.433 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=5, n_estimators=180;, score=0.402 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=6, n_estimators=30;, score=0.397 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, max_depth=6, n_estimators=30;, score=0.405 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, max_depth=6, n_estimators=30;, score=0.422 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, max_depth=6, n_estimators=80;, score=0.425 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=6, n_estimators=80;, score=0.433 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=6, n_estimators=80;, score=0.418 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=6, n_estimators=130;, score=0.417 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=6, n_estimators=130;, score=0.448 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=6, n_estimators=130;, score=0.402 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=6, n_estimators=180;, score=0.413 total time=   0.2s
# [CV 2/3] END learning_rate=0.1, max_depth=6, n_estimators=180;, score=0.444 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, max_depth=6, n_estimators=180;, score=0.410 total time=   0.2s
# [CV 1/3] END learning_rate=0.1, max_depth=7, n_estimators=30;, score=0.421 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, max_depth=7, n_estimators=30;, score=0.405 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, max_depth=7, n_estimators=30;, score=0.406 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, max_depth=7, n_estimators=80;, score=0.413 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=7, n_estimators=80;, score=0.452 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=7, n_estimators=80;, score=0.402 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=7, n_estimators=130;, score=0.413 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=7, n_estimators=130;, score=0.456 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=7, n_estimators=130;, score=0.394 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=7, n_estimators=180;, score=0.409 total time=   0.2s
# [CV 2/3] END learning_rate=0.1, max_depth=7, n_estimators=180;, score=0.460 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, max_depth=7, n_estimators=180;, score=0.398 total time=   0.2s
# [CV 1/3] END learning_rate=0.1, max_depth=8, n_estimators=30;, score=0.409 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, max_depth=8, n_estimators=30;, score=0.405 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, max_depth=8, n_estimators=30;, score=0.434 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, max_depth=8, n_estimators=80;, score=0.405 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=8, n_estimators=80;, score=0.448 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=8, n_estimators=80;, score=0.394 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=8, n_estimators=130;, score=0.425 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=8, n_estimators=130;, score=0.437 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, max_depth=8, n_estimators=130;, score=0.414 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, max_depth=8, n_estimators=180;, score=0.440 total time=   0.2s
# [CV 2/3] END learning_rate=0.1, max_depth=8, n_estimators=180;, score=0.452 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, max_depth=8, n_estimators=180;, score=0.406 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=3, n_estimators=30;, score=0.397 total time=   0.0s
# [CV 2/3] END learning_rate=0.5, max_depth=3, n_estimators=30;, score=0.401 total time=   0.0s
# [CV 3/3] END learning_rate=0.5, max_depth=3, n_estimators=30;, score=0.386 total time=   0.0s
# [CV 1/3] END learning_rate=0.5, max_depth=3, n_estimators=80;, score=0.405 total time=   0.0s
# [CV 2/3] END learning_rate=0.5, max_depth=3, n_estimators=80;, score=0.440 total time=   0.0s
# [CV 3/3] END learning_rate=0.5, max_depth=3, n_estimators=80;, score=0.398 total time=   0.0s
# [CV 1/3] END learning_rate=0.5, max_depth=3, n_estimators=130;, score=0.433 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=3, n_estimators=130;, score=0.433 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=3, n_estimators=130;, score=0.398 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=3, n_estimators=180;, score=0.421 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=3, n_estimators=180;, score=0.429 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=3, n_estimators=180;, score=0.410 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=4, n_estimators=30;, score=0.397 total time=   0.0s
# [CV 2/3] END learning_rate=0.5, max_depth=4, n_estimators=30;, score=0.401 total time=   0.0s
# [CV 3/3] END learning_rate=0.5, max_depth=4, n_estimators=30;, score=0.402 total time=   0.0s
# [CV 1/3] END learning_rate=0.5, max_depth=4, n_estimators=80;, score=0.417 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=4, n_estimators=80;, score=0.437 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=4, n_estimators=80;, score=0.390 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=4, n_estimators=130;, score=0.405 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=4, n_estimators=130;, score=0.437 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=4, n_estimators=130;, score=0.386 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=4, n_estimators=180;, score=0.405 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=4, n_estimators=180;, score=0.433 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=4, n_estimators=180;, score=0.382 total time=   0.3s
# [CV 1/3] END learning_rate=0.5, max_depth=5, n_estimators=30;, score=0.389 total time=   0.0s
# [CV 2/3] END learning_rate=0.5, max_depth=5, n_estimators=30;, score=0.425 total time=   0.0s
# [CV 3/3] END learning_rate=0.5, max_depth=5, n_estimators=30;, score=0.406 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=5, n_estimators=80;, score=0.409 total time=   0.2s
# [CV 2/3] END learning_rate=0.5, max_depth=5, n_estimators=80;, score=0.437 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=5, n_estimators=80;, score=0.386 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=5, n_estimators=130;, score=0.425 total time=   0.2s
# [CV 2/3] END learning_rate=0.5, max_depth=5, n_estimators=130;, score=0.413 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=5, n_estimators=130;, score=0.382 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=5, n_estimators=180;, score=0.429 total time=   0.3s
# [CV 2/3] END learning_rate=0.5, max_depth=5, n_estimators=180;, score=0.421 total time=   0.3s
# [CV 3/3] END learning_rate=0.5, max_depth=5, n_estimators=180;, score=0.375 total time=   0.3s
# [CV 1/3] END learning_rate=0.5, max_depth=6, n_estimators=30;, score=0.397 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=6, n_estimators=30;, score=0.433 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=6, n_estimators=30;, score=0.414 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=6, n_estimators=80;, score=0.413 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=6, n_estimators=80;, score=0.429 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=6, n_estimators=80;, score=0.402 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=6, n_estimators=130;, score=0.417 total time=   0.3s
# [CV 2/3] END learning_rate=0.5, max_depth=6, n_estimators=130;, score=0.433 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=6, n_estimators=130;, score=0.402 total time=   0.3s
# [CV 1/3] END learning_rate=0.5, max_depth=6, n_estimators=180;, score=0.401 total time=   0.8s
# [CV 2/3] END learning_rate=0.5, max_depth=6, n_estimators=180;, score=0.417 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=6, n_estimators=180;, score=0.406 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=7, n_estimators=30;, score=0.425 total time=   0.0s
# [CV 2/3] END learning_rate=0.5, max_depth=7, n_estimators=30;, score=0.433 total time=   0.0s
# [CV 3/3] END learning_rate=0.5, max_depth=7, n_estimators=30;, score=0.410 total time=   0.0s
# [CV 1/3] END learning_rate=0.5, max_depth=7, n_estimators=80;, score=0.417 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=7, n_estimators=80;, score=0.405 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=7, n_estimators=80;, score=0.398 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=7, n_estimators=130;, score=0.405 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=7, n_estimators=130;, score=0.437 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=7, n_estimators=130;, score=0.402 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=7, n_estimators=180;, score=0.409 total time=   0.2s
# [CV 2/3] END learning_rate=0.5, max_depth=7, n_estimators=180;, score=0.417 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=7, n_estimators=180;, score=0.382 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=8, n_estimators=30;, score=0.429 total time=   0.0s
# [CV 2/3] END learning_rate=0.5, max_depth=8, n_estimators=30;, score=0.429 total time=   0.0s
# [CV 3/3] END learning_rate=0.5, max_depth=8, n_estimators=30;, score=0.398 total time=   0.0s
# [CV 1/3] END learning_rate=0.5, max_depth=8, n_estimators=80;, score=0.417 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=8, n_estimators=80;, score=0.429 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=8, n_estimators=80;, score=0.414 total time=   0.1s
# [CV 1/3] END learning_rate=0.5, max_depth=8, n_estimators=130;, score=0.421 total time=   0.1s
# [CV 2/3] END learning_rate=0.5, max_depth=8, n_estimators=130;, score=0.429 total time=   0.1s
# [CV 3/3] END learning_rate=0.5, max_depth=8, n_estimators=130;, score=0.390 total time=   0.2s
# [CV 1/3] END learning_rate=0.5, max_depth=8, n_estimators=180;, score=0.429 total time=   0.2s
# [CV 2/3] END learning_rate=0.5, max_depth=8, n_estimators=180;, score=0.421 total time=   0.2s
# [CV 3/3] END learning_rate=0.5, max_depth=8, n_estimators=180;, score=0.386 total time=   0.2s
# {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 180}
# 0.4330772149497249
# ====================================================================================================
# ================== val 데이터로 평가 ====================
# [[25 18 22]
#  [21 30 20]
#  [15 16 22]]
#               precision    recall  f1-score   support
#
#        anger       0.41      0.38      0.40        65
#    happiness       0.47      0.42      0.44        71
#          sad       0.34      0.42      0.38        53
#
#     accuracy                           0.41       189
#    macro avg       0.41      0.41      0.41       189
# weighted avg       0.41      0.41      0.41       189
#
# ====================================================================================================
# ================== test 데이터로 평가 ====================
# [[31 34 16]
#  [21 39 29]
#  [13 29 24]]
#               precision    recall  f1-score   support
#
#        anger       0.48      0.38      0.42        81
#    happiness       0.38      0.44      0.41        89
#          sad       0.35      0.36      0.36        66
#
#     accuracy                           0.40       236
#    macro avg       0.40      0.39      0.40       236
# weighted avg       0.41      0.40      0.40       236

# %% [markdown]
# ## 성능 비교

# %%
test_result_df = pd.DataFrame(test_pred_result).T
test_result_df.columns = ['test_accuracy']
test_result_df
# Out:
#               test_accuracy
# SVM                0.377119
# RandomForest       0.398305
# XGB                0.389831
# LGBM               0.398305
